# %% [markdown]
# ### Fetching list of members from a slack channel

# %%
from slackclient import SlackClient

# %%
SLACK_BOT_TOKEN = 'xoxb-483237336743-488112887538-43uHT3X8c8OhPBYGFmEDqa4E'
slack_client = SlackClient(SLACK_BOT_TOKEN)

# %%
list_of_members = slack_client.api_call( "users.list",channel="learn-feed")

# %%
list_of_members['members'][2]
# Out:
# {'color': 'e96699',
#  'deleted': False,
#  'id': 'UE5HERGBT',
#  'is_admin': False,
#  'is_app_user': False,
#  'is_bot': False,
#  'is_owner': False,
#  'is_primary_owner': False,
#  'is_restricted': False,
#  'is_ultra_restricted': False,
#  'name': 'amitrv007',
#  'profile': {'avatar_hash': 'geab4dff4fcf',
#   'display_name': 'amitrv007',
#   'display_name_normalized': 'amitrv007',
#   'email': 'amitrv007@gmail.com',
#   'image_192': 'https://secure.gravatar.com/avatar/f4eab4dff4fcf8fe48a9bc479e36b661.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-192.png',
#   'image_24': 'https://secure.gravatar.com/avatar/f4eab4dff4fcf8fe48a9bc479e36b661.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-24.png',
#   'image_32': 'https://secure.gravatar.com/avatar/f4eab4dff4fcf8fe48a9bc479e36b661.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-32.png',
# ...

# %%
for mem in list_of_members['members']:
    print(mem['id'])
# Out:
# USLACKBOT
# UE5D8FP8Q
# UE5HERGBT
# UE5JKJQ1F
# UE5T0922U
# UE63FCWD9
# UE63Q2V7A
# UE65TLTRP
# UE6BQVCUD
# UE6KU1DJ4
# UE6PJAY7L
# UE76Z9WVD
# UE7714PMM
# UE7741JBZ
# UE779T41M
# UE7APUNJF
# UE7NCQDNX
# UE80NQFJ8
# UE8140N91
# UE81BFQV6
# UE91Q9DC2
# UE9DCV4JU
# UE9HCTJMA
# UE9JZD1V2
# UEAVCHZA4
# UEB17CM5E
# UEB2YU9NU
# UEB67QEJJ
# UEBK4H136
# UEBL95HDY
# UEBPN19FD
# UEBTZ216F
# UEBU47XPU
# UEC3AS3FU
# UEC53DGTF
# UECMN1Z2T
# UECS930BY
# UED4Q2AVA
# UEDB5UD8W
# UEDM5BP8R
# UEE5MS6JW
# UEF0KL31V
# UEF8CSAKY
# UEFE46SU9
# UEFR1DQMS
# UEGA62MS5
# UEJ9K0KKQ
# UEK1BEA9X
# UELRUDWL9
# UEMAXMHT5
# UEMB12DMF
# UEML8E8HZ
# UEMM0DK37
# UEN9Z83RD
# UEP81RME3
# UEP9BNP2A
# UEQ2N7MMM
# UEQA8BA3A
# UERD7GA7K
# UERDGS9UM
# UES2S8RLJ
# UES4DF83Z
# UESEP1ZSS
# UEWFC7Q14
# UH5KE89EC
# UH7MS1AKD
# UH7MVDYCT
# UH7Q1Q7JQ
# UH7QFJDC4
# UH7R841JP
# UH7UGSMK5
# UH88009B7
# UH94VDXJN
# UH98H5FQW
# UH99H2NBG
# UHA4DDG7P
# UHADG2G72
# UHDSLMRJ7
# UHF45K2R3
# UHPDMTJ8N
# UHXN02ET1
# ULX6CBMDH
# ULX6CP8QK
# ...

# %%
import requests
import json

# %%
# Set the webhook_url to the one provided by Slack when you create the webhook at https://my.slack.com/services/new/incoming-webhook/
url = 'https://slack.com/api/chat.postMessage'
slack_data = {'text': "Hello & Welcome to Mentorskool!"}

response = requests.post(
    url, data=json.dumps(slack_data),
    headers={'Content-Type': 'application/json'}
)
